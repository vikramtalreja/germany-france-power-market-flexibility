# %% [markdown]
# # Market fundamentals
#
# Status: outline only. No analysis has been executed.
#
# Load validated prices; compare zones; add demand and renewables; calculate residual load; export charts.
