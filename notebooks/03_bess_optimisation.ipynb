# %% [markdown]
# # BESS optimisation
#
# Status: outline only. No analysis has been executed.
#
# Define battery parameters; formulate Pyomo model; validate energy balance; compare sensitivities and document benchmark limitations.
